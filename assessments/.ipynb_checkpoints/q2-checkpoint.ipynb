# %%
import pandas as pd
from functools import reduce
import numpy as np
# def female_worker_percent(series): 
#     return (len(list(filter(lambda x: x == 'Female', series))) / len(series) * 100)

income = pd.read_csv('income.csv')
# income['count'] = 0
# x = income.groupby('native-country').agg({ 'count': len, 'hours-per-week': 'mean', 'gender': female_worker_percent})
# print(x)
income
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
isoutlier_workclass=(income.loc[:,'workclass']=='?')
income.loc[isoutlier_workclass,'workclass']=np.nan
isoutlier_occupation=(income.loc[:,'occupation']=='?')
income.loc[isoutlier_occupation,'occupation']=np.nan
df=income

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
print(np.sum( (income.loc[:,'workclass'].isnull())  ))
# Out:
# 0

# %%
print(len(df.loc[(df['workclass']==np.nan)]))
# Out:
# 0

# %%
print(np.sum( (income.loc[:,'workclass'].isnull())  ))
# Out:
# 2799

# %%
np.sum(income.loc[:,'workclass']=='Private')
# Out:
# 33906

# %%
income.loc[4,'workclass']
# Out:
# nan

# %%
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-cc04195da178> in <module>
# ----> 1 sum(np.isnan(df['workclass']))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     677
#     678         inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 679         result = getattr(ufunc, method)(*inputs, **kwargs)
#     680
#     681         name: Optional[Hashable]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
