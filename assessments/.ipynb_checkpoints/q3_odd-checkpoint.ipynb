# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('income.csv')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = np.arange(2)
incom_cat = ['<=50k', '>50k']
number = [len(df.loc[(df['income'] =='<=50K') & (df['gender']  == 'Male')]),len(df.loc[(df['income'] =='>50K') & (df['gender']  == 'Male')])]
ax.bar(incom_cat,number,alpha=0.6,width=0.25)
number = [len(df.loc[(df['income'] =='<=50K') & (df['gender']  == 'Female')]),len(df.loc[(df['income'] =='>50K') & (df['gender']  == 'Female')])]
ax.bar(incom_cat,number,alpha=0.6,color='red',width=0.2,align='edge')
# ax.set_xticks(np.arange(2))
plt.legend(['Male','Female'])
plt.xlabel('income category')
plt.ylabel('number of person')
plt.title('number of person based on income ')
plt.grid()
plt.show()

# %%
gender_column =df['gender']  == 'Female'
df.groupby(["marital-status", gender_column]).size().unstack(level=1).plot(kind='bar')
plt.legend(['Female','Male'])
plt.xlabel('marital-status')
plt.ylabel('number of person')
plt.title('number of person based on marital-status ')
plt.grid()
plt.show()

# %%
statuses = df['marital-status'].unique()
for status in statuses:
    pf=df.loc[(df['marital-status'] ==status)]
    plt.figure(figsize=(6,6))
    plt.title(status+" person histogram")
    plt.ylabel('Count')
    plt.xlabel('age')
    plt.hist(pf.loc[:,'age']);
    plt.grid()
