# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Create a dataFrame

# %%
my_dict={'color':['red','blue','black'],'density':[2,8,9]}
my_dict
# Out:
# {'color': ['red', 'blue', 'black'], 'density': [2, 8, 9]}

# %%
pd.DataFrame(my_dict)
# Out:
#    color  density
# 0    red        2
# 1   blue        8
# 2  black        9

# %%
name=['Tom','Krish','Nick']
age=[25,36,8]
New=list(zip(name,age))

# %%
df=pd.DataFrame(New,columns=['name','age'],index=['row1','row2','row3'])

# %%
df
# Out:
#        name  age
# row1    Tom   25
# row2  Krish   36
# row3   Nick    8

# %% [markdown]
# # Read a local file

# %%
df=pd.read_excel('../datasets/COVID-19-geographic-disbtribution-worldwide.xlsx')
df.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-11-13   13     11  2020    360      14             Afghanistan    AF
# 1 2020-11-12   12     11  2020    146       4             Afghanistan    AF
# 2 2020-11-11   11     11  2020      0       0             Afghanistan    AF
# 3 2020-11-10   10     11  2020    224      12             Afghanistan    AF
# 4 2020-11-09    9     11  2020     80       3             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           4.471402
# 1                                           3.848403
# ...

# %%
df.shape
# Out:
# (55296, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55296 entries, 0 to 55295
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     55296 non-null  datetime64[ns]
#  1   day                                                         55296 non-null  int64
#  2   month                                                       55296 non-null  int64
#  3   year                                                        55296 non-null  int64
#  4   cases                                                       55296 non-null  int64
#  5   deaths                                                      55296 non-null  int64
#  6   countriesAndTerritories                                     55296 non-null  object
# ...

# %% [markdown]
# # Select an index or column

# %%
df.countriesAndTerritories
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 55291       Zimbabwe
# 55292       Zimbabwe
# 55293       Zimbabwe
# 55294       Zimbabwe
# 55295       Zimbabwe
# Name: countriesAndTerritories, Length: 55296, dtype: object

# %%
df_ir=df[df.countriesAndTerritories=="Iran"]

# %%
df_ir
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 24554 2020-11-13   13     11  2020  11517     457                    Iran
# 24555 2020-11-12   12     11  2020  11780     462                    Iran
# 24556 2020-11-11   11     11  2020  10339     453                    Iran
# 24557 2020-11-10   10     11  2020  10463     458                    Iran
# 24558 2020-11-09    9     11  2020   9236     459                    Iran
# ...          ...  ...    ...   ...    ...     ...                     ...
# 24868 2020-01-04    4      1  2020      0       0                    Iran
# 24869 2020-01-03    3      1  2020      0       0                    Iran
# 24870 2020-01-02    2      1  2020      0       0                    Iran
# 24871 2020-01-01    1      1  2020      0       0                    Iran
# 24872 2019-12-31   31     12  2019      0       0                    Iran
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
df_ir=df_ir.drop(['countriesAndTerritories','geoId','countryterritoryCode','popData2019','continentExp','Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],axis=1)
df_ir
# Out:
#          dateRep  day  month  year  cases  deaths
# 24554 2020-11-13   13     11  2020  11517     457
# 24555 2020-11-12   12     11  2020  11780     462
# 24556 2020-11-11   11     11  2020  10339     453
# 24557 2020-11-10   10     11  2020  10463     458
# 24558 2020-11-09    9     11  2020   9236     459
# ...          ...  ...    ...   ...    ...     ...
# 24868 2020-01-04    4      1  2020      0       0
# 24869 2020-01-03    3      1  2020      0       0
# 24870 2020-01-02    2      1  2020      0       0
# 24871 2020-01-01    1      1  2020      0       0
# 24872 2019-12-31   31     12  2019      0       0
#
# [319 rows x 6 columns]

# %%
df_ir.loc[df_ir.duplicated(subset=['cases','deaths'],keep=False)]
# Out:
#          dateRep  day  month  year  cases  deaths
# 24634 2020-08-25   25      8  2020      0       0
# 24639 2020-08-20   20      8  2020      0       0
# 24777 2020-04-04    4      4  2020      0       0
# 24822 2020-02-19   19      2  2020      0       0
# 24823 2020-02-18   18      2  2020      0       0
# 24824 2020-02-17   17      2  2020      0       0
# 24825 2020-02-16   16      2  2020      0       0
# 24826 2020-02-15   15      2  2020      0       0
# 24827 2020-02-14   14      2  2020      0       0
# 24828 2020-02-13   13      2  2020      0       0
# 24829 2020-02-12   12      2  2020      0       0
# 24830 2020-02-11   11      2  2020      0       0
# 24831 2020-02-10   10      2  2020      0       0
# 24832 2020-02-09    9      2  2020      0       0
# 24833 2020-02-08    8      2  2020      0       0
# 24834 2020-02-07    7      2  2020      0       0
# 24835 2020-02-06    6      2  2020      0       0
# 24836 2020-02-05    5      2  2020      0       0
# ...

# %%
df_ir.loc[df_ir.duplicated(subset=['cases','deaths'],keep='first')]
# Out:
#          dateRep  day  month  year  cases  deaths
# 24639 2020-08-20   20      8  2020      0       0
# 24777 2020-04-04    4      4  2020      0       0
# 24822 2020-02-19   19      2  2020      0       0
# 24823 2020-02-18   18      2  2020      0       0
# 24824 2020-02-17   17      2  2020      0       0
# 24825 2020-02-16   16      2  2020      0       0
# 24826 2020-02-15   15      2  2020      0       0
# 24827 2020-02-14   14      2  2020      0       0
# 24828 2020-02-13   13      2  2020      0       0
# 24829 2020-02-12   12      2  2020      0       0
# 24830 2020-02-11   11      2  2020      0       0
# 24831 2020-02-10   10      2  2020      0       0
# 24832 2020-02-09    9      2  2020      0       0
# 24833 2020-02-08    8      2  2020      0       0
# 24834 2020-02-07    7      2  2020      0       0
# 24835 2020-02-06    6      2  2020      0       0
# 24836 2020-02-05    5      2  2020      0       0
# 24837 2020-02-04    4      2  2020      0       0
# ...

# %%
df_ir.loc[df_ir.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [dateRep, day, month, year, cases, deaths]
# Index: []

# %%
df_ir.drop(df_ir.loc[df_ir.duplicated(keep='first')].index)
# Out:
#          dateRep  day  month  year  cases  deaths
# 24554 2020-11-13   13     11  2020  11517     457
# 24555 2020-11-12   12     11  2020  11780     462
# 24556 2020-11-11   11     11  2020  10339     453
# 24557 2020-11-10   10     11  2020  10463     458
# 24558 2020-11-09    9     11  2020   9236     459
# ...          ...  ...    ...   ...    ...     ...
# 24868 2020-01-04    4      1  2020      0       0
# 24869 2020-01-03    3      1  2020      0       0
# 24870 2020-01-02    2      1  2020      0       0
# 24871 2020-01-01    1      1  2020      0       0
# 24872 2019-12-31   31     12  2019      0       0
#
# [319 rows x 6 columns]

# %%
df_ir.drop_duplicates(keep='first',inplace=True,ignore_index=True)

# %%
df_ir.sum()
# Out:
# day         4928
# month       1837
# year      644379
# cases     726585
# deaths     40121
# dtype: int64

# %%
df_ir.cases.sum()
# Out:
# 726585

# %%
df_ir.count()
# Out:
# dateRep    319
# day        319
# month      319
# year       319
# cases      319
# deaths     319
# dtype: int64

# %%
df_ir.shape
# Out:
# (319, 6)

# %%
df_ir.cumsum
# Out:
# <bound method DataFrame.cumsum of        dateRep  day  month  year  cases  deaths
# 0   2020-11-13   13     11  2020  11517     457
# 1   2020-11-12   12     11  2020  11780     462
# 2   2020-11-11   11     11  2020  10339     453
# 3   2020-11-10   10     11  2020  10463     458
# 4   2020-11-09    9     11  2020   9236     459
# ..         ...  ...    ...   ...    ...     ...
# 314 2020-01-04    4      1  2020      0       0
# 315 2020-01-03    3      1  2020      0       0
# 316 2020-01-02    2      1  2020      0       0
# 317 2020-01-01    1      1  2020      0       0
# 318 2019-12-31   31     12  2019      0       0
#
# [319 rows x 6 columns]>

# %%
plt.plot(df_ir.cases.cumsum(skipna=True))

# %%
df_ir.cases.max()
# Out:
# 11780

# %%
df_ir.cases.idxmax()
# Out:
# 1

# %%
df_ir.cases.mean()
# Out:
# 2277.69592476489

# %%
df_ir.deaths.mean()
# Out:
# 125.77115987460814

# %%
df_ir.deaths.mean()/24
# Out:
# 5.24046499477534

# %%
df_ir.deaths.median()/24
# Out:
# 4.875

# %%
df_ir.describe()
# Out:
#               day       month         year         cases     deaths
# count  319.000000  319.000000   319.000000    319.000000  319.00000
# mean    15.448276    5.758621  2019.996865   2277.695925  125.77116
# std      8.878441    3.036680     0.055989   2093.191115  109.50093
# min      1.000000    1.000000  2019.000000      0.000000    0.00000
# 25%      8.000000    3.000000  2020.000000   1017.000000   48.00000
# 50%     15.000000    6.000000  2020.000000   2166.000000  117.00000
# 75%     23.000000    8.000000  2020.000000   2670.500000  184.00000
# max     31.000000   12.000000  2020.000000  11780.000000  462.00000

# %% [markdown]
# # Percent change

# %%
plt.plot(df_ir.deaths.pct_change())

# %%
plt.plot(df_ir.deaths.pct_change(periods=30))

# %%
plt.scatter(df_ir.cases,df_ir.deaths)

# %%
df_ir.corr()
# Out:
#              day     month      year     cases    deaths
# day     1.000000 -0.050910 -0.098381 -0.028239  0.009988
# month  -0.050910  1.000000 -0.115438  0.774209  0.800468
# year   -0.098381 -0.115438  1.000000  0.061116  0.064511
# cases  -0.028239  0.774209  0.061116  1.000000  0.919294
# deaths  0.009988  0.800468  0.064511  0.919294  1.000000

# %%
df_ir.dateRep[0]
# Out:
# Timestamp('2020-11-13 00:00:00')

# %%
from  persiantools.jdatetime import JalaliDate

# %%
JalaliDate.to_jalali(2020,11,13)
# Out:
# JalaliDate(1399, 8, 23, Jomeh)

# %%
def def_to_jalali (in_str):
    y= int(in_str[:4])
    m= int(in_str[5:7])
    d=int(in_str[8:10])
    return JalaliDate.to_jalali(y,m,d)

# %%
df_ir.dateRep=[str(s) for s in df_ir.dateRep]

# %%
# df_ir.dateRep.apply(def_to_jalali)

# %%
df_ir.dateRep.apply(lambda x :JalaliDate.to_jalali(int(x[:4]), int(x[5:7]),int(x[8:10])))
# Out:
# 0      1399-08-23
# 1      1399-08-22
# 2      1399-08-21
# 3      1399-08-20
# 4      1399-08-19
#           ...
# 314    1398-10-14
# 315    1398-10-13
# 316    1398-10-12
# 317    1398-10-11
# 318    1398-10-10
# Name: dateRep, Length: 319, dtype: object

# %%
df_ir.dateRep
# Out:
# 0     2020-11-13
# 1     2020-11-12
# 2     2020-11-11
# 3     2020-11-10
# 4     2020-11-09
#          ...
# 314   2020-01-04
# 315   2020-01-03
# 316   2020-01-02
# 317   2020-01-01
# 318   2019-12-31
# Name: dateRep, Length: 319, dtype: datetime64[ns]
